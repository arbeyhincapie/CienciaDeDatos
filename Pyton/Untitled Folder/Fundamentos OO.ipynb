# %% [markdown]
# # Clase

# %%
class Vehiculo:
    pass

# %%
carro = Vehiculo()
print(carro)

# %% [markdown]
# # Ya se creó objeto en python

# %%
class vehi:    
    def __init_(self, numero_llantas, color, numero_puertas):
        self.numero_llantas = numero_llandas
        self.color = color
        self.numero_puertas = numero_puertas

# %%
ferrari500 = vehi(4, 'rojo', 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-43d5059511d1> in <module>()
# ----> 1 ferrari500 = vehi(4, 'rojo', 5)
#
# TypeError: object() takes no parameters

# %%
class estudiante:
    def __init__(self, nombre, cedula, semestre):
        self.nombre = nombre
        self._cedula = cedula
        self.semestre = semestre
        self.edad = 20
        
    def Cedula(self):
        return self.Cedula()
    def MostrarCed

# %%
maria = estudiante("maria", 38463784, 5)

# %%
print(maria.edad)
# Out:
# 21

# %%
maria.edad = 21

# %%
pow(2, 2)
# Out:
# 4
