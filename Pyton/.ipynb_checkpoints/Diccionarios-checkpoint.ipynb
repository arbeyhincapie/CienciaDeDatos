# %%
Diccionario = {'Col' : 'Colombia', 'USA' : 'UnitedStates'}

# %%
Diccionario
# Out:
# {'Col': 'Colombia', 'USA': 'UnitedStates'}

# %%
Diccionario['USA']
# Out:
# 'UnitedStates'

# %%
for elemento in Diccionario.items():
    print(elemento)
# Out:
# ('Col', 'Colombia')
# ('USA', 'UnitedStates')

# %% [markdown]
# # en lugar de "items"; Key para clave, value para valor

# %%
Diccionario['per'] = 'peru'

# %%
Diccionario
# Out:
# {'Col': 'Colombia', 'USA': 'UnitedStates', 'per': 'peru'}
