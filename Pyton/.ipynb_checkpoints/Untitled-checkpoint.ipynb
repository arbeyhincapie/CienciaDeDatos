# %% [markdown]
# # aCLARAR COMPARACION

# %%
def CompararLis(Lista1, Lista2):
    len(Lista1)
    len(Lista2)
    if len(Lista1) > len(Lista2):
        print("Lista 1 mayor elementos")
    else:
        print("Lista 2 mayor elementos")
        
CompararList(Lista1 = [2,4,5,4,3,2], Lista2 = [2,4,3,2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f4e65ede9295> in <module>()
#       7         print("Lista 2 mayor elementos")
#       8
# ----> 9 CompararList(Lista1 = [2,4,5,4,3,2], Lista2 = [2,4,3,2])
#
# NameError: name 'CompararList' is not defined

# %%
def CompararLis(Lista1, Lista2):
    len(Lista1)
    len(Lista2)
    if len(Lista1) > len(Lista2):
        print("Lista 1 mayor elementos")
    else:
        print("Lista 2 mayor elementos")
        
CompararLis(Lista1 = [2,4,5,4,3,2], Lista2 = [2,4,3,2,45,58,14])
# Out:
# Lista 2 mayor elementos

# %%
def CompararLis(Lista1, Lista2):
    len(Lista1)
    len(Lista2)
    if len(Lista1) > len(Lista2):
        print("Lista 1 mayor elementos")
    elif len(Lista1) < len(Lista2):
        print("Lista 2 mayor elementos")  
    else: 
         print("Listas iguales")
        
CompararLis(Lista1 = [2,4,5,4,3,2,7], Lista2 = [2,4,3,2,45,58,14])
# Out:
# Listas iguales

# %%
def ICM(Peso,Estat):
    return = Peso / Estat ** 2
# Out:
#   File "<ipython-input-15-254d4ad01ac0>", line 2
#     return = Peso / Estat ** 2
#            ^
# SyntaxError: invalid syntax

# %%
ICM(85, 125)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-73e995e1232d> in <module>()
# ----> 1 ICM(85, 125)
#
# <ipython-input-12-cd66a4f75e87> in ICM(Peso, Estat)
#       1 def ICM(Peso,Estat):
# ----> 2     Mult = Peso / pow(Estat)
#       3     return Mult
#
# TypeError: pow expected at least 2 arguments, got 1

# %%
def ICM(Peso,Estat):
    Mul = Peso / Estat ** 2
    return Mul
ICM(85, 1.70)
# Out:
# 29.411764705882355
