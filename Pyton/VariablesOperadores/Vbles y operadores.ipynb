# %%
MiVble = "hola curso"

# %%
print MiVble
# Out:
#   File "<ipython-input-2-1d871f0913c8>", line 1
#     print MiVble
#                ^
# SyntaxError: Missing parentheses in call to 'print'

# %%
print(MiVble)
# Out:
# hola curso

# %%
type(MiVble)
# Out:
# str

# %%
MiVble=2
print(MiVble)
type MiVble
# Out:
#   File "<ipython-input-5-2b42a55793e5>", line 3
#     type MiVble
#               ^
# SyntaxError: invalid syntax

# %%
MiVble=2
print(MiVble)
type(MiVble)
# Out:
# 2
# int

# %%
MiFloat = 3.5
print(MiFloat)
type(MiFloat)
# Out:
# 3.5
# float

# %%
MiBolean = True 
print(MiBolean)
type(MiBolean)
# Out:
# True
# bool

# %%
MiVariable = True
MiVariable1 = True
Resultado = MiVariable and MiVaribale1
print Resultado
# Out:
#   File "<ipython-input-9-41d770c86bd3>", line 4
#     print Resultado
#                   ^
# SyntaxError: Missing parentheses in call to 'print'

# %%
Resultado = MiVariable and MiVaribale1
print(Resultado)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-e732195af6e1> in <module>()
# ----> 1 Resultado = MiVariable and MiVaribale1
#       2 print(Resultado)
#
# NameError: name 'MiVariable' is not defined

# %%
Resultado = MiVariable and MiVariable1
print(Resultado)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-0d366896e4e9> in <module>()
# ----> 1 Resultado = MiVariable and MiVariable1
#       2 print(Resultado)
#
# NameError: name 'MiVariable' is not defined

# %%
MiVariable = True
MiVariable1 = True
Resultado = MiVariable and MiVariable1
print(Resultado)
# Out:
# True

# %%
Resultado1 = not (MiVariable or (not (MiVariable1 and MiVariable)))

# %%
print(Resultado1)
# Out:
# False

# %%
MiIgualdad = 100
MiComparacion = 100
MiIgualdad == MiComparacion
# Out:
# True

# %%
MiIgualdad != MiComparacion
# Out:
# False

# %%
Padre = "El papa"
Hijo = Padre
Hijo is not Padre
# Out:
# False

# %%
hijo = "El hijo"

hijo is Padre
# Out:
# False

# %%
hija = "El papa"
hija is Padre
# Out:
# False

# %%
Compara = 50
Compara2 = 93
Compara > Compara2
# Out:
# False

# %%
Compara <= Compara2
# Out:
# True

# %%
Compara <= 50
# Out:
# True

# %%
Compara2 >=93
# Out:
# True

# %%
Compara3=45
Compara4=34

Compara + (((Compara2 *compara3)/(Compara4**Compara4))+(Compara3%6))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-cda5a621baee> in <module>()
#       2 Compara4=34
#       3
# ----> 4 Compara + (((Compara2 *compara3)/(Compara4**Compara4))+(Compara3%6))
#
# NameError: name 'compara3' is not defined

# %%
Compara + (((Compara2 *Compara3)/(Compara4**Compara4))+(Compara3%6))
# Out:
# 53.0

# %%
"""jbgcvhisdgfaashifgasdhifhias"""
# Out:
# 'jbgcvhisdgfaashifgasdhifhias'
